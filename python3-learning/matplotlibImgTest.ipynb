# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import os

os.getcwd()
# Out:
# 'D:\\PyProjects\\AI\\python3Learning'

# %%
img = imread('img/lxr.png')
plt.imshow(img)

plt.show()
